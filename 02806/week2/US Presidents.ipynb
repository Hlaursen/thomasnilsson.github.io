# %%
import pandas as pd

# %%
data = pd.read_csv('data/pres.csv').drop("Number",1)

# %%
data.Name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-70a4442b9b9e> in <module>()
# ----> 1 data.Name
#
# /Users/thomasnilsson/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Name'

# %%
data
# Out:
#            Name   Months
# 0    Washington       94
# 1         Adams       48
# 2     Jefferson       96
# 3       Madison       96
# 4        Monroe       96
# 5         Adams       48
# 6       Jackson       96
# 7     Van Buren       48
# 8      Harrison        1
# 9         Tyler       47
# 10         Polk       48
# 11       Taylor       16
# 12      Filmore       32
# 13       Pierce       48
# 14     Buchanan       48
# 15      Lincoln       49
# 16      Johnson       47
# 17        Grant       96
# 18        Hayes       48
# 19     Garfield        7
# 20       Arthur       41
# 21    Cleveland       48
# 22     Harrison       48
# 23    Cleveland       48
# 24     McKinley       54
# 25    Roosevelt       90
# 26         Taft       48
# 27       Wilson       96
# 28      Harding       29
# 29     Coolidge       67
# 30       Hoover       48
# 31    Roosevelt      146
# 32       Truman       92
# 33   Eisenhower       96
# 34      Kennedy       34
# 35      Johnson       62
# ...
